# %%
# Initialize Otter
import otter
grader = otter.Notebook("cs109b_hw1.ipynb")

# %% [markdown]
# # <img style="float: left; padding-right: 10px; width: 45px" src="https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/iacs.png"> CS109B Data Science 2: Advanced Topics in Data Science
# ## Homework 1 - Clustering
#
#
#
#
# **Harvard University**<br/>
# **Spring 2023**<br/>
# **Instructors**: Mark Glickman & Pavlos Protopapas
#
#
# <hr style="height:2pt">

# %%
# RUN THIS CELL 
import requests
from IPython.core.display import HTML
styles = requests.get("https://raw.githubusercontent.com/Harvard-IACS/2018-CS109A/master/content/styles/cs109.css").text
HTML(styles)
# Out:
# <style>
# blockquote { background: #AEDE94; }
# h1 {
#     padding-top: 25px;
#     padding-bottom: 25px;
#     text-align: left;
#     padding-left: 10px;
#     background-color: #DDDDDD;
#     color: black;
# }
# h2 {
#     padding-top: 10px;
#     padding-bottom: 10px;
#     text-align: left;
#     padding-left: 5px;
#     background-color: #EEEEEE;
#     color: black;
# }
#
# div.exercise {
# 	background-color: #ffcccc;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
# div.exercise-r {
# 	background-color: #fce8e8;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# }
#
#
# span.sub-q {
# 	font-weight: bold;
# }
# div.theme {
# 	background-color: #DDDDDD;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 18pt;
# }
# div.gc {
# 	background-color: #AEDE94;
# 	border-color: #E9967A;
# 	border-left: 5px solid #800080;
# 	padding: 0.5em;
# 	font-size: 12pt;
# }
# p.q1 {
# ...

# %% [markdown]
# <hr>
#
# #### Instructions
# - To submit your assignment follow the instructions given in Canvas.
# - Plots should be legible and interpretable without having to refer to the code that generated them, including labels for the $x$- and $y$-axes as well as a descriptive title and/or legend when appropriate.
# - When asked to interpret a visualization, do not simply describe it (e.g., "the curve has a steep slope up"), but instead explain what you think the plot *means*.
# - Autograding tests are mostly to help you debug. The tests are not exhaustive so passing a test is necessary but not sufficient for full credit.
# - The use of *extremely* inefficient or error-prone code (e.g., copy-pasting nearly identical commands rather than looping) may result in only partial credit.
# - We have tried to include all the libraries you may need to do the assignment in the imports cell provided below. Please get course staff approval before importing any additional 3rd party libraries.
# - Enable scrolling output on cells with very long output.
# - Feel free to add additional code or markdown cells as needed.
# - Ensure your code runs top to bottom without error and passes all tests by restarting the kernel and running all cells (note that this can take a few minutes).
# - **You should do a "Restart Kernel and Run All Cells" before submitting to ensure (1) your notebook actually runs and (2) all output is visible**
#
# <hr>

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time

from gap_statistic import OptimalK
from scipy.spatial.distance import pdist
from scipy.cluster.hierarchy import dendrogram, fcluster, ward
from scipy.cluster import hierarchy
from sklearn.cluster import KMeans, DBSCAN
from sklearn.decomposition import PCA
from sklearn.metrics import silhouette_samples, silhouette_score
from sklearn.neighbors import NearestNeighbors
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
# measure notebook runtime
time_start = time.time()

# %% [markdown]
# <hr style="height:2pt">

# %% [markdown]
# <a id="contents"></a>
#
# # Notebook Contents
#
# - [**Problem 1 [37.5 pts]: Clustering with k-means**](#part1)
#
# - [**Problem 2 [37.5 pts]: Other Ks**](#part2)
#
# - [**Problem 3 [25 pts]: Alternative Algorithms**](#part3)

# %% [markdown]
# <div class="theme">FMA: A Dataset For Music Analysis </div>
#
# In this assignment, you will be working with data collected from The Free Music Archive (https://freemusicarchive.org/). The Free Music Archive is an online repository of original music from independent artists that can be freely downloaded as an mp3.
#
# The provided `fma_new.csv` contains 9,354 rows.
#
# In this subset of the FMA data, each music track is represented by a total of 82 summary audio features:
#
# 8 interpretable features extracted by Echonest (now Spotify):\
# `acousticness`, `danceability`, `energy`, `instrumentalness`, `liveness`, `speechiness`, `tempo`, `valence`
#
#
# 74 abstract audio features computated across the run time of the track using the [librosa](https://librosa.org/doc/latest/index.html) python package and then averaged.
#
# For those interestend in more information about the FMA dataset please see the paper and GitHub repository (https://github.com/mdeff/fma)

# %% [markdown]
# <a id="part1"></a>
#
# ## <div class='exercise'>Part 1: Clustering with k-means </div>
#
# [Return to contents](#contents)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q1.1 Loading Data, Scaling, and KMeans Clustering</b></div>
#
# Begin by reading `data/fma_new.csv` into a Pandas DataFrame called `fma`.
#
# You can assume that this particular subset of the FMA data includes 12 different music genres. So we'll begin by assuming there are 12 clusters.
#
# But before we begin clustering we should standardize the dataset so that all features have mean of 0 and standard deviation of 1. In this way the distance metric used by out clustering algorithms will not be affect by the arbitrary scale of the features. Save the standardized data in DataFrame called `fma_scaled` which has the same column names as `fma`.
#
# Next, run the k-means clustering algorithm on the scaled data using the `KMeans` class from `sklearn.cluster`, setting the number of clusters to 12, `n_init` to 25, and the `random_state` to 109.  Save the fitted KMeans object as `km12`.

# %%
# your code here

fma = pd.read_csv("/Users/jamesliounis/Documents/Harvard SM DS/AC209b/Problem Sets/cs109b_hw1/data/fma_new.csv")

# Standardizing dataset

# Create standard scaler object
# StandardScaler class is used to standardize the features of the data by 
# transforming the data such that it has a mean of 0 and a standard deviation of 1.
scale = StandardScaler()

# Fit the StandardScaler object to the data
fma_scaled = pd.DataFrame(scale.fit_transform(fma), columns = fma.columns)

# %%
# your code here

# Save the fitted KMeans object 
km12 = KMeans(n_clusters = 12, n_init = 25, random_state = 109).fit(fma_scaled)

# %%
grader.check("q1.1")
# Out:
# q1.1 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q1.2 Evaluating $k=12$</b></div>
#
# The provided `silplot` function creates two subplots: one displays the silhouette scores for each datapoint across all clusters and the other shows a projection of the data onto its first 2 principal components. In both subplots the assigned cluster labels are encoded by color.
#
# How reasonable does the clustering with $k=12$ appear? Use your understanding of the silhouette scores and PCA projection to support your position.

# %%
#modified code from http://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

def silplot(X, cluster_labels, clusterer, pointlabels=None):
    n_clusters = clusterer.n_clusters
    
    # Create a subplot with 1 row and 2 columns
    fig, (ax1, ax2) = plt.subplots(1, 2)
    fig.set_size_inches(12,7)

    # The 1st subplot is the silhouette plot
    # The silhouette coefficient can range from -1, 1 but in this example we 
    # will set a lower limit on the x-axis to keep the plot small
    ax1.set_xlim([-0.2, 1])
    
    # The (n_clusters+1)*10 is for inserting blank space between silhouette
    # plots of individual clusters, to demarcate them clearly.
    ax1.set_ylim([0, len(X) + (n_clusters + 1) * 10])

    # The silhouette_score gives the average value for all the samples.
    # This gives a perspective into the density and separation of the formed
    # clusters
    silhouette_avg = silhouette_score(X, cluster_labels)
    print(f"For n_clusters = {n_clusters}, the average silhouette_score is {silhouette_avg}.")

    # Compute the silhouette scores for each sample
    sample_silhouette_values = silhouette_samples(X, cluster_labels)

    y_lower = 10
    for i in range(0,n_clusters):
        # Aggregate the silhouette scores for samples belonging to
        # cluster i, and sort them
        ith_cluster_silhouette_values = \
            sample_silhouette_values[cluster_labels == i]

        ith_cluster_silhouette_values.sort()

        size_cluster_i = ith_cluster_silhouette_values.shape[0]
        y_upper = y_lower + size_cluster_i

        color = plt.cm.nipy_spectral(float(i) / n_clusters)
        ax1.fill_betweenx(np.arange(y_lower, y_upper),
                          0, ith_cluster_silhouette_values,
                          facecolor=color, edgecolor=color, alpha=0.7)

        # Label the silhouette plots with their cluster numbers at the middle
        ax1.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

        # Compute the new y_lower for next plot
        y_lower = y_upper + 10  # 10 for the 0 samples

    ax1.set_title("The silhouette plot for the various clusters.")
    ax1.set_xlabel("The silhouette coefficient values")
    ax1.set_ylabel("Cluster label")

    # The vertical line for average silhouette score of all the values
    ax1.axvline(x=silhouette_avg, color="red", linestyle="--")

    ax1.set_yticks([])  # Clear the yaxis labels / ticks
    ax1.set_xticks([-0.2, 0, 0.2, 0.4, 0.6, 0.8, 1])

    # 2nd Plot showing the actual clusters formed
    colors = plt.cm.nipy_spectral(cluster_labels.astype(float) / n_clusters)
    
    # axes will be first 2 PCA components
    
    pca = PCA(n_components=2).fit(X.values)
    X_pca = pca.transform(X.values) 
    ax2.scatter(X_pca[:, 0], X_pca[:, 1], marker='.', s=200, lw=0, alpha=0.35,
                c=colors, edgecolor='k')
    xs = X_pca[:, 0]
    ys = X_pca[:, 1]    

    
    if pointlabels is not None:
        for i in range(len(xs)):
            plt.text(xs[i],ys[i],pointlabels[i])

    # Labeling the clusters (transform to PCA space for plotting)
    centers = pca.transform(clusterer.cluster_centers_)
    # Draw white circles at cluster centers
    ax2.scatter(centers[:, 0], centers[:, 1], marker='o',
                c="white", alpha=1, s=200, edgecolor='k')

    for i, c in enumerate(centers):
        ax2.scatter(c[0], c[1], marker='$%d$' % int(i), alpha=1,
                    s=50, edgecolor='k')

    ax2.set_title("The visualization of the clustered data.")
    ax2.set_xlabel("PC1 ({}%)".format(np.round(100*pca.explained_variance_ratio_[0],1)))
    ax2.set_ylabel("PC2 ({}%)".format(np.round(100*pca.explained_variance_ratio_[1],1)))

    plt.suptitle(("Silhouette analysis for KMeans clustering on sample data "
                  "with n_clusters = %d" % n_clusters),
                 fontsize=14, fontweight='bold')

# %% [markdown]
# **Answer to Q1.2**
#
# Considering the clustering visualization alongside the silhouette score enables us to conclude that the clustering with $k = 12$ is *not* very reasonable. There are multiple reasons for this:
# - Setting $k = 12$ does not allow for a clear separation of clusters. Data points are overlapping, meaning the clustering is unclear
# - The red vertical line in the silhouette plot denotes the 'average silhouette score'. A fair amount of clusters here have many points which are to the left of that line i.e., below the average silhouette score (if the silhouette score of an observation is below the average silhouette score of all observations, it means that the observation is not well-matched to its own cluster and might be better assigned to a different cluster)
# - A lot of clusters even have *negative* silhouette scores: this indicates that an observation is poorly matched to its assigned cluster, meaning it is more similar to other observations in a different cluster than to its own cluster, which depicts the aforementioned "overlap"
# - The compactness of the clusters is clearly unequal: cluster 4 seems to be significantly larger than 3, 2, and 0, for example

# %%
# your code here
silplot(fma_scaled, km12.labels_, km12, pointlabels=None)
# Out:
# For n_clusters = 12, the average silhouette_score is 0.04987327481584193.

# %% [markdown]
# <!-- END QUESTION -->
#
# <a id="part2"></a>
#
# ## <div class='exercise'>Part 2: Other Ks </div>
#
# [Return to contents](#contents)
#
# Our choice of $k=12$ was just a guess based on the fact that we've been told there are 12 genres represented in this data.\
# We'll now look at some metrics we can use to evaluate a set of clusters.
#
# **For questions in this section (Part 2) you should work with a sample of 2,000 data points drawn with the DataFrame `sample`method and a random seed of 109.**

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.1 Inertia</b></div>
#
# Here you'll use the elbow method to evaluate the best choice of $k$, plotting the total inertia of each k-means clustering for $k \in \{1,2,...,15\}.$
#
# Running kmeans across many values of $k$ can take a long time so we'll take a few steps to speed things up.
#
# First, you should only be clustering a subset of the scaled data in this section (part 2). Using the DataFrame's `sample` method with a `random_state` of 109, sample 2,000 data points and store them in `processed_sample`.
#
# Next, when fiting each KMeans object, use only 10 initializations and a random state of 109 as before.
#
# Finally, create a well labeled plot of inertia as a function of $k$ and describe what value(s) of $k$ might be considered optimal with respect to this plot and why.
#
# **Note:** recall that inertia is twice the total within-cluster variation

# %% [markdown]
# **Answer to Q2.1**
#
# The inertia is given by:
#
# $\text{inertia or WCSS} = \sum_{i=1}^{k} \sum_{x \in C_i} \left| x - \mu_i \right|^2$
#
# where $C_i$ is the set of points in the $i$-th cluster, and $μ_i$ is the mean (centroid) of the $i$-th cluster.
#
# From the expression, we can see that the inertia measures the sum of squared distances between each data point and its nearest cluster center. As the number of clusters increases, the inertia decreases as the clusters become smaller and tighter. However, beyond a certain point, the decrease in the inertia slows down and levels off, which corresponds to the optimal number of clusters. This corresponds to the number of clusters that provides a good balance between the loss of information caused by having too few clusters and the increase in complexity caused by having too many clusters.Thus, finding the optimal-$k$ is equivalent to finding the elbow or knee point in the plot of the inertia as a function of the number of clusters.
#
# In this case, $k=2$ and $k=4$ seem to be good choices, but the kink is more defined for the former, suggesting that it is the optimal number of clusters.

# %%
# your code here

processed_sample = fma_scaled.sample(n=2000, random_state = 109)

# %%
# Create a function to train the KMeans algorithm

def train_kmeans(X, k):
    # Implementing required specifications
    kmeans = KMeans(n_clusters = k, random_state = 109, n_init = 10)
    # Training on data
    kmeans.fit(X)
    # Return fitted object
    return kmeans

ks = [i for i in range(1, 16)]

# Saving ks and fitted models in a dictionary in order to reuse later
model_dic = {f"k={k}":train_kmeans(processed_sample, k) for k in ks}

# Saving inertias in a separate object
inertias = [model.inertia_ for model in model_dic.values()]

# %%
plt.plot(ks, inertias, 'o-')
plt.xticks(ks);
plt.xlabel('Number of clusters, $k$')
plt.ylabel('inertia')
plt.title('KMeans: inertia as a function of $k$');

# %%
grader.check("q2.1")
# Out:
# q2.1 results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.2 Silhouette Score</b></div>
#
# Using the labels from each of the 15 fitted KMeans objects in the previous question, calculate the average silhouette scores and store them in `sil_scores`.
#
# Plot the average silhouette scores in `sil_scores` as a function of $k$. Describe what value(s) of $k$ might be considered optimal with respect to this plot and why.
#
# **Hints:**
# * If you stored your results from Q2.1 you shouldn't have to refit any KMeans objects here
# * `silhouette_score` will throw an error if you try and score labels containing only a single cluster. Note that the silhouette score when $k=1$ is definte to be 0.

# %% [markdown]
# **Answer to Q2.2**
#
# Given a set of N data points, the silhouette score for each observation $i$ is defined as:
#
# $s_i = \frac{b_i - a_i}{\max(a_i, b_i)}$
#
# where $a_i$ is the average distance between observation $i$ and all other observations in the same cluster, and $b_i$ is the minimum average distance between observation $i$ and observations in all other clusters.
#
# Using once again the "elbow method", we look for a kink in the below plot, where the average silhouette score starts to decline or level off. This corresponds to the number of clusters that provides a good balance between the loss of information caused by having too few clusters and the increase in complexity caused by having too many clusters.
#
# This is clearly the case for $k=2$.

# %%
# Initializing empty list to store silhouette scores
sil_scores = []


# Iterating through the previously trained models that are stored in a dictionary
for model in model_dic.values():
    
    # We start by trying to append silhouette scores whenever possible
    try:
        sil_scores.append(silhouette_score(processed_sample, model.labels_)) 
    # In the event of ValueError, set silhouette score to 0 as per instructions
    except ValueError:
        sil_scores.append(0)

# Plot

# Setting figure size
plt.figure(figsize=(8, 6))
# Plot silhouette scores as a function of number of clusters
plt.plot(ks, sil_scores, 'x-')

# Evidencing highest silhouette score, marking it clearly on plot
max_silhouette_score = ks[np.argmax(sil_scores)]
plt.axvline(ks[np.argmax(sil_scores)], c='r', ls='--', 
            label=f"Highest attained silhouette score ($k$={max_silhouette_score})")
plt.xticks(ks);
plt.xlabel('Number of clusters, $k$')
plt.ylabel('Silhouette Score')
plt.title('KMeans: Silhouette Score as a function of $k$')
plt.legend();

# %%
grader.check("q2.2")
# Out:
# q2.2 results: All test cases passed!

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.3 Gap Statistic</b></div>
#
# Use the gap statistic to evaluate the choice of the number of clusters for k-means clustering with $k \in \{1,2,..,15\}$. Again, use `processed_sample` rather than the entire dataset to save time.
#
# Create a well-labeled plot showing the gap statistic as a function of the number of clusters.
#
# Describe the rule for picking the optimum number of clusters described in [the original gap statistic paper](https://hastie.su.domains/Papers/gap.pdf) (this is the method referred to in lecture as allowing for some "slack").

# %% [markdown]
# **Note:** This implementation of gap statistic has a [difficulties with reproducibility](https://github.com/milesgranger/gap_statistic/issues/59) so don't worry if your results change across runs. Setting a random seed with numpy and setting OptimalK's `n_jobs=1` helps, but it makes everything run unbearably slow.
#
# **Hint:** The [gap_statistic GitHub repo](https://github.com/milesgranger/gap_statistic) is a good place to find information about the `OptimalK` object and its attributes.

# %%
# to ignore the frame.append warning described here:
# https://github.com/milesgranger/gap_statistic/issues/57
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# **Answer to Q2.3**
#
# According to the Tibshirani et al. paper, the Gap statistic measures the difference between the WCSS of observed data and an expected WCSS under a null reference distribution (often assumed to be a *uniform* distribution). It helps determine the best number of clusters in a data set by comparing the WCSS of observed data with the WCSS of the reference distribution.
#
# The formula for calculating Gap statistic is:
#
# $$Gap(k) = E_n^{}logT_k^{(b)} - logT_k$$
#
# where $k$ represents the number of clusters, $W_k$ is the WCSS (see previous WCSS equation) of observed data with $k$ clusters, and $E_n^{}logW_k^{}$ is the expected WCSS under the reference distribution. In the algorithm described in the paper, we start by computing it at each iteration (for each generated dataset $b = 1,...,B$, and for each $k$). We then compute the standard deviation of $K$, $\text{sd(K)}$. We finally choose the number of clusters as the smallest $K$ s.t.:
#
# $$\text{Gap(K)} \geq(K+1) - s_{K+1}$$
#
# where $s_{K+1} = \text{sd(K+1)}\sqrt(1+1/B)$
#
# This means that the optimal number of clusters is the value of $k$ at which the Gap statistic first starts to level off and no longer increases as $k$ increases. This value is typically identified by looking for an "elbow" in the Gap statistic plot. This is the **"stopping condition"**.
#
# The Tibshirani paper sets the stopping condition by observing the trend of the gap statistic as the number of clusters increases. The iteration ends when the gap statistic reaches its maximum value or flattens out, showing that adding more clusters no longer significantly improves the results. The stopping condition is typically set when the gap statistic levels off or starts to decline, reflecting a change in the rate of improvement, allowing to identify the optimal number of clusters for the given data set.

# %%
# your code here

# instantiate OptimalK with recommended specification
# OptimalK is a Python library that can be used to determine the optimal number of 
# clusters in a dataset. The class takes a single parameter, 
# "n_jobs", which specifies the number of parallel jobs to run. 
# In this case, "n_jobs" is set to 1, meaning that only one job will be run in parallel.

optimalK = OptimalK(n_jobs = 1)

# Calling OptimalK

#`n_refs` specifies the number of reference datasets 
# used to compute the Gap statistic  
# `cluster_array` refers to the potential number of clusters, passed in array form
n_clusters = optimalK(processed_sample, cluster_array = np.array(ks), n_refs=500)

print('Optimal number of clusters:', n_clusters)
# Out:
# Optimal number of clusters: 14

# %% [markdown]
# In this case, the plot that is required by the question is the **first** one.

# %%
optimalK.plot_results()

# %%
# Need to be skeptical about the gap statistic, focus on distribution
# Slack method

# %%
# your code here
# Use the stopping condition described in the original paper
...
# Out:
# Ellipsis

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.4 Choose a Best $k$</b></div>
#
# After analyzing the plots produced by all three of these metrics, discuss the number of k-means clusters that you think is the best fit for this dataset. Defend your answer with evidence from the three graphs produced here and what you surmise about this dataset. Store your choice in `best_k`.

# %% [markdown]
# **Answer to Q2.4**
#
# Referring to the Github repo (and the docstring for the plotting of `optimalK`), we know that we have the following plots:
#
# """
# - (1) A plot of the "Gap value" - as defined in the original Tibshirani et
# al paper - versus $n$, the number of clusters.
# - (2) A plot of diff versus $n$, the number of clusters, where $\text{diff} =
# Gap(k) - Gap(k+1) + s_{k+1}$. The original Tibshirani et al. paper
# recommends choosing the smallest k such that this measure is positive.
# - (3) A plot of the Gap* value - a variant of the Gap statistic suggested
# in "A comparison of Gap statistic definitions with and with-out
# logarithm function" [https://core.ac.uk/download/pdf/12172514.pdf],
# which simply removes the logarithm operation from the Gap calculation -
# versus *n*, the number of clusters (Mohajer et al, 2011)
# - (4) A plot of the diff* value versus n, the number of clusters. diff*
# corresponds to the aforementioned diff value for the case of Gap*.
#
# """
#
# In this case, looking at 1) and 2) does not clearly give us an optimal $k$. We do not observe a well-defined kink in 1), which is why the algorithm retrieves $15$ as optimal $k$, which we take with scepticism. Using the decision-rule outlined by the authors, there is no significantly positive "diff" in 2) for our values of $k$. This analysis is inconclusive.
#
# Therefore, it is more interesting in this case to resort to the Mohajer et al. paper for our choice of $k$ (plots 3 & 4). According to these authors, removing the logarithm from the calculation palliates the over-estimation of the number of clusters, which arises in  the case of overlapping clusters (as evidenced in our answer to 1.2). In this sense, while the Gap statistic is better for detecting non-overlapping clusters, Gap* is more appropriate in this setting as it corrects for the tendency of Gap to overestimate the number of clusters in the presence of overlapping clusters. Hence, basing our choice on these 2 last plots clearly shows **$k=2$** as optimal.
#
# Intuitively, the choice of using 2 clusters instead of 4 makes sense when considering the nature of the dataset and the type of data it contains. It is important to recall that there are only four distinct categories of recordings: live recordings, albums, radio programs, and standalone tracks. Given this information, it is reasonable to assume that utilizing two clusters instead of four would be more appropriate for this dataset. This is because the different categories of recordings can be grouped into pairs based on their similarities in regards to the measured variables. For instance, one could group albums and standalone tracks together, as albums are simply collections of individual tracks. Additionally, live recordings and radio programs can also be paired, as radio programs often consist of live recordings.

# %%
fma.head()
# Out:
#    acousticness  danceability    energy  instrumentalness  liveness  \
# 0      0.416675      0.675894  0.634476          0.010628  0.177647
# 1      0.374408      0.528643  0.817461          0.001851  0.105880
# 2      0.043567      0.745566  0.701470          0.000697  0.373143
# 3      0.951670      0.658179  0.924525          0.965427  0.115474
# 4      0.452217      0.513238  0.560410          0.019443  0.096567
#
#    speechiness    tempo   valence  chroma_cens_01  chroma_cens_02  ...  \
# 0     0.159310  165.922  0.576661        0.474300        0.369816  ...
# 1     0.461818  126.957  0.269240        0.232784        0.229469  ...
# 2     0.124595  100.260  0.621661        0.258420        0.303385  ...
# 3     0.032985  111.562  0.963590        0.229882        0.286978  ...
# 4     0.525519  114.290  0.894072        0.249513        0.253561  ...
#
#    spectral_contrast_06  spectral_contrast_07  spectral_rolloff_01  \
# ...

# %%
best_k = 2

# %%
grader.check("q2.4")
# Out:
# q2.4 results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q2.5 Visualize & Interpret Best $k$ Results</b></div>
#
# Fit KMeans on the *entire scaled dataset* using your choice of `best_k`, 25 initializations, and a random state of 109. Store the KMeans object in `km_best` and the resulting labels in `km_labels`.
#
# Next, use `silplot` to visualize these clusters and their silhouette scores.
#
# How do these plots differ from the previous pair, and what might that mean about the clusterings? Would you consider your kmeans clustering with `best_k` successful?

# %% [markdown]
# **Answer to Q2.5**
#
# In this case, one may argue that clustering with `best_k` was more successful than previously. There is significantly less overlapping, and the clusters are better outlined. However, even if there is little to no overlapping, the clusters are far from distinct: there is a line down the middle where the clusters could very well be assigned to the wrong cluster (right plot).
#
# This can be confirmed by the silhouette plot, where even with a 226% increase in average silhouette score (from $k=12$ case), the silhouette scores are once again concentrated in the majority to the *left* of (i.e., below) the average silhouette score. This suggests that a lot of these observations may have been assigned to the wrong cluster, or it could be a result of intrinsic characteristics of the object that make it different from the other objects in its cluster. We even still have *negative* silhouette scores, for cluster 1 ($\approx{-0.1}$), which means that some of these observations are better matched to observations in cluster 0 than they are to observations in cluster 1.
#
# In conclusion, whilst the overall clustering for $k=2$ is better than the previous clustering, it can still be improved.

# %%
# your code here

# fitting a K-Means clustering model on the scaled dataset, 
# setting number of clusters to the optimal number
km_best = KMeans(n_clusters = best_k, n_init = 25, random_state = 109).fit(fma_scaled)
km_best
# Out:
# KMeans(n_clusters=2, n_init=25, random_state=109)

# %%
# Storing labels in a variable
km_labels = km_best.labels_

# %%
silplot(fma_scaled, km_labels, km_best, pointlabels=None)
# Out:
# For n_clusters = 2, the average silhouette_score is 0.16569139147003403.

# %%
grader.check("q2.5")
# Out:
# q2.5 results: All test cases passed!

# %% [markdown]
# <a id="part3"></a>
#
# ## <div class='exercise'>Part 3: Alternative Algorithms </div>
#
# [Return to contents](#contents)

# %% [markdown]
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.1: Hierarchical Clustering</b></div>
#
# Run agglomerative clustering using Ward's method and plot the result using a dendrogram.
#
# Next, create a well-labeled plot of average silhoutte score as a function of the number of clusters, again with $k \in \{1,2,..,15\}$. To do this you'll need to produce a series of 'flat' cluster labels using `fcluster` for each value of $k$ and then use those labels to calculate the averate silhouette scores.
#
# Use information from the dedrogram and silhouette scores plot to justify a choice for the optimal number of clusters. Store this interger in `maxclust`. Then use  to find the 'flat' cluster labels produced when `maxclust` is used as the maximum number of clusters. Store these labels in `hac_labels`.
#
# **Hint:**
# - When using a lot of data, rendering an x-axis label for each observation can make the dendrogram plotting very slow. Try setting `no_labels=True`.
# - Inspect the unique cluster labels produced by `fcluster`. Notice how they are numbered. Keep this in mind as you may need to alter the labels if you plan to use them with functions that expect labels to be encoded like those from KMeans.

# %% [markdown]
# **Answer to Q3.1**
#
# Dividing the dendrogram at $k=4$ will result in imbalanced clusters. As a matter of fact, given that setting $k=2$ would result in imbalanced clusters, setting $k=4$ would only exacerbate this (we can see this from the difference in size between left/orange and right/green clusters). Dividing at $k=2$ shows a slightly more balanced dendrogram: clusters are more similar in size, resulting in an appropriate separation of the data. This is why we settle for a division in 2 clusters.
#
# This can be confirmed by looking at the silhouette scores plot, where the kink is evidently at $k=2$. For reasons outlined previously, we decide that this is the best number of clusters.

# %%
# your code here

# Computing the pairwise distances between the objects in the feature matrix of the 
# dataset using the Euclidean distance metric. We use The function pdist from 
# the scipy.spatial.distance library is used to compute these distances.

# `pdist` function takes a 2D array as input and returns a 1D condensed distance matrix, 
# which represents the pairwise distances between all the objects in the feature matrix

y = pdist(fma_scaled, metric='euclidean')

# Computing the linkage matrix for the dataset using the Ward linkage method
Z = ward(y)

# %%
# number of clusters

# Setting number of clusters to 2 as per our justification to represent threshold
k=2
plt.figure(figsize=(14,10))


# threshold where we 'cut' the dendrogram
thresh = Z[-(k-1),2]
# draw dendrogram
dendrogram(Z, color_threshold=thresh, no_labels=True)

# show a subset of xtick labels so it isn't too cluttered
ticks, labels = plt.xticks()
step = 5
plt.xticks(ticks[::step], labels[::step], fontsize=13)

# horizontal line at threshold
plt.axhline(thresh, ls='--', c='k', label='$k=2$');
plt.suptitle("Hierarchical Clustering of Spotify Data")
plt.ylabel("Within cluster variation")
plt.title("Method: Ward");
plt.legend();

# %%
# Generating a series of hierarchical clustering solutions for a range of values 
# for k and storing each solution as an array in a dictionary, 
# where the key is the string representation of the number of clusters used in 
# the solution.

# The `fcluster` function takes as inputs the linkage matrix (Z), 
# the number of clusters (k),
# and the criterion for determining the cluster assignments (criterion='maxclust')
fclusters = {f"k={k}":fcluster(Z, k, criterion='maxclust') for k in ks}

# Inspecting fclusters to see how they're labelled
fclusters
# Out:
# {'k=1': array([1, 1, 1, ..., 1, 1, 1], dtype=int32),
#  'k=2': array([2, 2, 2, ..., 2, 2, 2], dtype=int32),
#  'k=3': array([2, 2, 2, ..., 3, 2, 2], dtype=int32),
#  'k=4': array([2, 2, 2, ..., 3, 2, 2], dtype=int32),
#  'k=5': array([3, 3, 3, ..., 4, 3, 3], dtype=int32),
#  'k=6': array([4, 4, 4, ..., 5, 4, 4], dtype=int32),
#  'k=7': array([5, 5, 5, ..., 6, 5, 5], dtype=int32),
#  'k=8': array([5, 5, 5, ..., 6, 5, 5], dtype=int32),
#  'k=9': array([6, 6, 6, ..., 7, 6, 6], dtype=int32),
#  'k=10': array([6, 7, 7, ..., 8, 7, 6], dtype=int32),
#  'k=11': array([7, 8, 8, ..., 9, 8, 7], dtype=int32),
#  'k=12': array([ 8,  9,  9, ..., 10,  9,  8], dtype=int32),
#  'k=13': array([ 8,  9,  9, ..., 10,  9,  8], dtype=int32),
#  'k=14': array([ 8,  9,  9, ..., 11,  9,  8], dtype=int32),
#  'k=15': array([ 9, 10, 10, ..., 12, 10,  9], dtype=int32)}

# %%
# Computing silhouette scores for each of the hierarchical clustering solutions 
# stored in the fclusters dictionary

# Initializes an empty list to store the silhouette scores for each of the clustering 
# solutions
# We set the first element of this list to be 0 because
# `silhouette_score` will throw an error if you try and score labels containing 
# only a single cluster 
sil_scores = [0]

# Iterate over the values in the `fclusters` dictionary (omitting the first value, 
# see above) 
for model in list(fclusters.values())[1::]:
    # inputs to the silhouette_score function are the scaled feature matrix of 
    # the dataset (`processed_sample`) 
    # and the clustering solution (`model`)
    sil_scores.append(silhouette_score(fma_scaled, model))
    

# Plot
plt.plot(ks, sil_scores, 'x-', color='purple')
plt.xticks(ks)
plt.xlabel('Number of clusters, $k$')
plt.ylabel('Silhouette Score')
plt.title('KMeans: Silhouette Score as a function of $k$');

# %%
maxclust = 2

# We use the index in our previously defined structure
hac_labels = fclusters['k='+str(maxclust)]

# %%
grader.check("q3.1")
# Out:
# q3.1 results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.2: DBSCAN</b></div>
#
# Create a well-labeled knee plot to determine an optimal epsilon for when the min point parameter is 5. Then run DBSCAN on the data using your choice of `episilon` and the speficied `min_samples=5`.
#
# Store all labels produced in `dbscan_labels`.\
# Store the number of *clusters* found by the algorithm in `dbscan_n_clusters`.
#
# Inspect the number of points that were assigned to each *label*. What does this tell you about the clusters and give a geometric interpretation of what kind of data might lead to this result of DBSCAN?

# %% [markdown]
# **Answer to Q3.2**
#
# At the bend/knee, we can see that the distance is roughly $43$, which we choose for our value of $\epsilon$.
#
# All of the points seem to have been assigned to only one label. It is interesting to recall here the prowess of the DBSCAN algorithm, taking into account the fact that it is *density-based* (it groups together points that are close to each other in the feature space and separates points that are far away): it works great on data that has "interesting shapes" in it, like concentric circles, for example. However, in this case it is applied on data where all the points are located in high density region with no specific distinct shapes.
#
# Therefore, because the data in this case has no distinct shape, the majority of the points are density-reachable from the starting point which results in one giant cluster.

# %%
# Defines a function called "plot_epsilon" that takes two parameters as input:

# - "df": a Pandas DataFrame with the data to be plotted
# - "min_samples": the minimum number of samples required 
#   for a data point to be considered as a core point in DBSCAN

def plt_epsilon(df, min_samples):
    
    # Create an NearestNeighbors object class 
    # Fitting it to the input DataFrame 
    fitted_neigbors = NearestNeighbors(n_neighbors=min_samples).fit(df)
    
    # Apply "kneighbors" method to fitted object and input DataFrame 
    # to determine the distances and indices of the nearest neighbors of each data point
    distances, indices = fitted_neigbors.kneighbors(df)
    
    # Plots the k-th nearest neighbor distances (i.e., the epsilon values) 
    # for each data point
    
    # Extracts the distances to the k-th nearest neighbor 
    # for each data point and stores them in a variable
    dist_to_nth_nearest_neighbor = distances[:,-1]
    plt.plot(np.sort(dist_to_nth_nearest_neighbor))
    plt.title('$\epsilon$ as a function of increasing distances', fontsize=10)
    plt.xlabel("Index\n(sorted by increasing distances)")
    plt.ylabel("{}-NN Distance (epsilon)".format(min_samples-1))
    plt.tick_params(right=True, labelright=True)
    

# Invoke above function on scaled data, min_samples=5
plt_epsilon(fma_scaled, 5)

# %%
# your code here


# Fit DBSCAN model to the scaled data with maximum distance between samples 
# `eps=43` and minimum number of samples in a neighborhood `min_samples=5`

dbscan_fitted = DBSCAN(eps=43, min_samples=5).fit(fma_scaled)

# %%
# Access the labels_ attribute of the fitted DBSCAN model object:

dbscan_labels = dbscan_fitted.labels_

# Count the number of occurrences of each unique label
unique, counts = np.unique(dbscan_labels, return_counts=True)

# Print the results
for label, count in zip(unique, counts):
    print(f"Label {label}: {count} samples")
# Out:
# Label 0: 9354 samples

# %%
# your code here

# Using the fact that clusters labelled as "-1" are outliers, 
# we only consider clusters that are greater or equal to 0

dbscan_n_clusters = (np.unique(dbscan_labels) >= 0).sum()

print("Number of DBSCAN clusters:", dbscan_n_clusters)
# Out:
# Number of DBSCAN clusters: 1

# %%
grader.check("q3.2")
# Out:
# q3.2 results: All test cases passed!

# %% [markdown]
# <!-- END QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <!-- BEGIN QUESTION -->
#
# <div class='exercise'><b>Q3.3</b></div>
#
# Load `data/track_info.csv` into the Dataframe `track_info` and inspect it. This track info corresponds to the data in `fma` row-for-row.
#
# Create a well-labeled plot or set of subplots that visualize the 'top genre' make-up of each cluster designated by the three sets of labels: `km_labels`, `hac_labels`, and `dbscan_labels`.
#
# What does your visualization demonstrate about how each clustering compares to the genre labels? Does any one clustering seem more successful at capturing genre distinctions?
#
# **Hint:** There are many ways you could approach this visuallization task. Experiment! You may also find it helpful to create plotting functions to handle some parts of the visualization if they are being repeated with slightly different parameters (e.g., cluster labels).

# %% [markdown]
# **Answer to Q3.3**
#
# We need to consider 3 details in the analysis of our visualisations:
#
# - 1. Consistency of genre distribution:
#
# If a cluster has a dominant genre in one clustering method, but a different genre is dominant in another method, it suggests that the clusters are not well-defined, and the clustering method may not be capturing the genre distinctions effectively. In this case, "Rock" seems to dominate across clustering methods, with at least one cluster evidencing it as the dominant genre. In this regard, the clustering seems to be effective at capturing genre distinctions.
#
#
# - 2. Size and separation of clusters:
#
# One may note here that the clusters are very imbalanced in terms of size. In 2/3 methods, there is one cluster that is much bigger than the other. For the cluster that is too large between the two, this suggests that it may be grouping together data points that are too dissimilar. For the one that is too small, this may mean that it is not effective in capturing distinctions between the data. Hence, the clustering in all 3 methods does not perform well in this regard. KMeans provides the best balance and separation of clusters,  with cluster 1 being roughly half the size of 0.
#
# - 3. Variety and distribution of genres:
#
# Because we opted for a small number of clusters in the first two methods, it is normal that both clusters contain a large number of genres. However, although in different proportions, genres seem to be represented in both clusters. This makes it challenging to interpret clusters, but in this case it may also be due in some tracks being loosely classified on Spotify in terms of genre. In this regard, HAC performs best: Rock and Electronic dominate cluster 2, and are only weakly present in 1. Inversely, Old Time / Historic dominates 1.
#
#
# Overall, HAC is probably the best in capturing distinctions as it performs well in 2/3 of the above metrics. Despite producing unbalanced clusters, it still boasts a coherent composition in its clusters (Electronic, Pop and Rock go well together in 2, and Old Time and Classical in 1).

# %%
track_info = pd.read_csv("/Users/jamesliounis/Documents/Harvard SM DS/AC209b/Problem Sets/cs109b_hw1/data/track_info.csv")
track_info.head()
# Out:
#   artist_name   track_title track_genre_top track_genres_all
# 0        AWOL          Food         Hip-Hop      ['Hip-Hop']
# 1        AWOL  Electric Ave         Hip-Hop      ['Hip-Hop']
# 2        AWOL    This World         Hip-Hop      ['Hip-Hop']
# 3   Kurt Vile       Freeway             Pop          ['Pop']
# 4        AWOL  Street Music         Hip-Hop      ['Hip-Hop']

# %%
# Create a subplot for each set of labels
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15,10))

# In all of these plots, we need to pass the color argument explicitly in order
# to avoid colors being repeated
# For this, we use hexadecimal color codes

# Plot kmeans labels
track_info.groupby(km_labels)["track_genre_top"].value_counts().unstack().plot(kind='bar', 
                                                                               stacked=True, ax=ax1, color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', 
          '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#aec7e8', '#ffbb78'])
ax1.set_title("KMeans Labels", fontsize=15)

# Plot hierarchical clustering labels
track_info.groupby(hac_labels)["track_genre_top"].value_counts().unstack().plot(kind='bar', 
                                                                                stacked=True, ax=ax2, color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', 
          '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#aec7e8', '#ffbb78'])

ax2.set_title("Hierarchical Clustering Labels", fontsize=15)

# Plot DBSCAN labels
track_info.groupby(dbscan_labels)["track_genre_top"].value_counts().unstack().plot(kind='bar', 
                                                                                   stacked=True, ax=ax3, color = ['#1f77b4', '#ff7f0e', '#2ca02c', '#d62728', '#9467bd', '#8c564b', 
          '#e377c2', '#7f7f7f', '#bcbd22', '#17becf', '#aec7e8', '#ffbb78'])
ax3.set_title("DBSCAN Labels", fontsize=15)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Plot the top genre make-up of each cluster designated by km_labels
plt.figure(figsize=(10,8))
plt.subplot(131)
sns.countplot(x=km_labels, hue=track_info["track_genre_top"])
plt.xticks(rotation=90)
plt.title("KMeans Labels"); 

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Plot the top genre make-up of each cluster designated by hac_labels
plt.figure(figsize=(10,8))
plt.subplot(132)
sns.countplot(x=hac_labels, hue=track_info["track_genre_top"])
plt.title("Hierarchical Clustering Labels");


plt.tight_layout(); 
plt.show()

# %%
# Plot the top genre make-up of each cluster designated by dbscan_labels
plt.figure(figsize=(10,8))
plt.subplot(133)
sns.countplot(x=dbscan_labels, hue=track_info["track_genre_top"])
plt.title("DBSCAN Labels")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# <!-- END QUESTION -->
#
# <a id="bonus"></a>
#
# ## <div class='exercise'>Wrap-up</div>
#
# [Return to contents](#contents)

# %% [markdown]
# The only required section here is to report the amount of time you spent on this assignment.
#
# You are encouraged to use this space to continue to explore the fma dataset. You could:
# - Try different clustering methods (e.g., total linkage)
# - Attempt feature selection, engineering, or dimentionality reduction before clustering
# - Sample points from clusters and inspect their track information to get an idea what a cluster might represent
# - Find the nearest neighbors in the feature space to a track of interest
# - Pull in new data from the [FMA project](https://github.com/mdeff/fma). There are thousands of additional tracks to use (these were just the only ones that also had the Spotify features and track info available). And there are also hundreds of additional (abstract) audio feature columns that can be used.

# %% [markdown]
# How many hours did you spend working on this assignment?

# %%
time_spent_on_hw = 5

# %% [markdown]
# **TOTAL LINKAGE**

# %% [markdown]
# Total linkage clustering creates clusters by merging samples that have the minimum distance between them. This method is sensitive to outliers and can result in long, string-like clusters. It is suitable for creating clusters from samples that have well-defined boundaries, and where clusters are likely to be separated by areas of low sample density.
#
# In our case, we saw that our clusters were not particularly well defined in multiple occasions, which is why we are able to retrieve only one cluster and our dendrogram is not particularly meaningful. HAC seems to remain a better approach in this case.

# %%
from scipy.cluster.hierarchy import linkage, dendrogram

# Perform hierarchical clustering using total linkage method
Z = linkage(fma_scaled, method='complete')

# Plot dendrogram
dendrogram(Z, no_labels=True)
plt.title('Hierarchical clustering of Spotify Data with Total Linkage')
plt.show()

# %%
# Determine the number of clusters
max_d = 50
total_linkage_clusters = fcluster(Z, max_d, criterion='distance')
print("Number of clusters: ", len(set(total_linkage_clusters)))
# Out:
# Number of clusters:  1

# %% [markdown]
# **Attempt feature selection, engineering, or dimentionality reduction before clustering**

# %% [markdown]
# **1. Feature Selection**
#
# Feature selection seems complicated in this case. A lot of these features seem to be very specific musical characteristics, which would require an excellent musical background to see which ones would probably be less relevant to clustering. We run a high risk of eliminating features that may nonetheless be important in this case, and thus choose to leave it as such.

# %% [markdown]
# **2. Feature Engineering**
#
# It can be interesting here to keep the *interpretable* features, and then add additional ones that would indicate an average between ones that are closely related. This could help better capture the effect of features that "go well together".
#
# In this case:
# - `acousticness`and `instrumentalness` are similar. We can average them in `avg_1`
# - `danceability`, `energy`, `tempo` and `liveness` can be `avg_2`
# - `valence` and `speechiness` can be `avg_3`
#
#
# Additionally, when it comes to the *abstract* features, we can do the same and add extra features that will represent the average of all from the same category.
#
# Applying all of this shows an increase in average silhouette score from $.161$ to almost $.17$, which definitely shows that we're on the right track.

# %%
# Create a copy of df
fma_engineered = fma.copy()

# Create average columns (see markdown above)
fma_engineered['avg_1'] = np.mean(fma_engineered['acousticness']+fma_engineered['instrumentalness'])
fma_engineered['avg_2'] = np.mean(fma_engineered['danceability']+fma_engineered['energy']+fma_engineered['tempo']+fma_engineered['liveness'])
fma_engineered['avg_3'] = np.mean(fma_engineered['valence']+fma_engineered['speechiness'])

# Abstract columns: "chroma"

# Select the columns whose names begin with abstract keyword
chroma_cols = [col for col in fma_engineered.columns if col.startswith("chroma")]
mfcc_cols = [col for col in fma_engineered.columns if col.startswith("mfcc")]
tonnetz_cols = [col for col in fma_engineered.columns if col.startswith("tonnetz")]
spectral_cols = [col for col in fma_engineered.columns if col.startswith("spectral")]

# Calculate the average of the values in these columns and add as a new column
fma_engineered["chroma_mean"] = fma_engineered[chroma_cols].mean(axis=1)
fma_engineered["mfcc_mean"] = fma_engineered[mfcc_cols].mean(axis=1)
fma_engineered["tonnetz_mean"] = fma_engineered[tonnetz_cols].mean(axis=1)
fma_engineered["spectral_mean"] = fma_engineered[spectral_cols].mean(axis=1)

# %%
# Scale engineered dataframe
fma_eng_scaled = pd.DataFrame(scale.fit_transform(fma_engineered), 
                              columns = fma_engineered.columns)

# Fit kmeans:
km_eng = KMeans(n_clusters = 2, n_init = 25, random_state = 109).fit(fma_eng_scaled)

silplot(fma_eng_scaled, km_eng.labels_, km_eng, pointlabels=None)
# Out:
# For n_clusters = 2, the average silhouette_score is 0.17267496056623477.

# %% [markdown]
# **3. Dimensionality reduction**
#
# PCA decompostion definitely seems to be an important step to carry out! Average silhouette score is now $.44$, with barely any silhouette scores below 0! PC1 seems to explain most of the variation in the data with $73.5 %$%

# %%
# Perform PCA for dimensionality reduction
pca = PCA(n_components=2)
fma_reduced = pca.fit_transform(fma_scaled)

# Apply K-means clustering
kmeans = KMeans(n_clusters=2)
labels_pca = kmeans.fit_predict(fma_reduced)

# %%
km_pca = KMeans(n_clusters = best_k, n_init = 25, random_state = 109).fit(fma_reduced)
silplot(pd.DataFrame(fma_reduced), km_pca.labels_, km_pca, pointlabels=None)
# Out:
# For n_clusters = 2, the average silhouette_score is 0.44901271732608605.

# %%
grader.check("bonus")
# Out:
# bonus results: All test cases passed!

# %%
time_end = time.time()
print(f"It took {(time_end - time_start)/60:.2f} minutes for this notebook to run")
# Out:
# It took 2.58 minutes for this notebook to run

# %% [markdown]
# **This concludes HW1. Thank you!**
